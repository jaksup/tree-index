# %%
# !pip install pdfminer.six
# !pip install summa
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 941.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for summa: filename=summa-1.2.0-py3-none-any.whl size=54388 sha256=6036c9c2108cf37489269be33cbae2cbee162a32d5d50ad98768395cc13c3c09
#   Stored in directory: /root/.cache/pip/wheels/4a/ca/c5/4958614cfba88ed6ceb7cb5a849f9f89f9ac49971616bc919f
# Successfully built summa
# ...

# %%
from pdfminer.high_level import extract_text

import pdfminer

text = extract_text('/content/sample_data/cyfryzacja.pdf')
print(repr(text))
# Out:
# 'Departament Gospodarki Cyfrowej\n\n1. Wpływ działań na realizację celów Cyfrowej Dekady\n\nDziałania w ramach Drogi do Cyfrowej Dekady, realizowane lub planowane do realizacji, \nmożna odnieść do poszczególnych celów (patrz tabela poniżej). Wszystkie działania zostały \nszczegółowo opisane w rozdziale 4.\n\nNazwa działania\n\nIntensywnoś\nć cyfrowa\n\nChmura\n\nDuże zbiory \ndanych\n\nSztuczna \ninteligencja\n\nTCP.I.1. Portal www.biznes.gov.pl i\xa0Konto \nPrzedsiębiorcy\n\nTCP.I.2. Program Certyﬁkacji \nCyberbezpieczeństwa dla Biznesu\n\nTCP.I.3. Elektronizacja umów pracodawców \nz\xa0pracownikami lub zleceniobiorcami – \ncyfryzacja procesów kadrowych \nw\xa0przedsiębiorstwach\n\nTCP.I.4. Program Europejskich Hubów \nInnowacji Cyfrowych – ośrodek typu one-\nstop-shop dla cyfrowej transformacji MŚP\n\nTCP.I.5. Program AI dla ﬁrm – program \nszkoleniowo-doradczy dla pracowników \ni\xa0managerów MŚP w\xa0dziedzinie podstaw \ni\xa0wdrażania rozwiązań sztucznej inteligencji \nw\xa0ﬁrma
# ...

# %%
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

output_string = StringIO()
with open('RIS300427_bijlage (1).pdf', 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)

text = output_string.getvalue()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-09839d22e6c9> in <cell line: 11>()
#       9
#      10 output_string = StringIO()
# ---> 11 with open('RIS300427_bijlage (1).pdf', 'rb') as in_file:
#      12     parser = PDFParser(in_file)
#      13     doc = PDFDocument(parser)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'RIS300427_bijlage (1).pdf'

# %%
text
# Out:
# "Inkoopstrategie \n\n(uitwerking uitgangspuntennotitie)  \n  \nRegio Haaglanden, 2020 -2024  \n\n  \n  \n\n  \n\n \n\n    \n    \n    \n    \n     \n\n  \n\n \n\n  \n\n \n\n1  \n\n\x0cInhoud \n1 \n\nInleiding ......................................................................................... 3 \nDe visie en doelen van de gemeenten in Regio Haaglanden .................................................. 4 \n\n1.1 \n\n1.2 \n\nHet bredere zorglandschap ..................................................................................................... 5 \n\n1.3 \n\nScope inkoopstrategie ............................................................................................................. 7 \n\n1.4 \n\nRelatie met andere domeinen ................................................................................................. 7 \n\n1.5 \n\nOpbouw van de inkoopstrategie ............................................................................................. 8 \n\n2  De ni
# ...

# %%
    import summa

    data1 = str(text)
    data = data1.replace('\n', '')

    from summa.summarizer import summarize
    summary = summarize(data, language='english', words=250)

    print("\nYour document summary\n")
    print(summary)

    from textblob import TextBlob
    from summa import keywords
    keywords1 = keywords.keywords(summary,words=10,language='polish')

    #nl_blob = TextBlob(keywords1)
    #nl_blob.detect_language()


    #keywords2 = nl_blob.translate(to='en')
    #keywords = str(keywords2)

    print("\nProposed keywords\n")
    print(keywords1)
# Out:
# Your document summary
#
# ...
